# %% [markdown]
# ### import  libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import os

# %% [markdown]
# ### Explore dataset

# %%
file=os.path.join(os.getcwd(),'heart_2020_cleaned.csv')
df=pd.read_csv(file)

# %%
df.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
# 3           No  24.21      No              No     No             0.0
# 4           No  23.71      No              No     No            28.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0          30.0          No  Female        55-59  White      Yes
# 1           0.0          No  Female  80 or older  White       No
# 2          30.0          No    Male        65-69  White      Yes
# 3           0.0          No  Female        75-79  White       No
# 4           0.0         Yes  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good        5.0    Yes            No        Yes
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  object
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  object
#  3   AlcoholDrinking   319795 non-null  object
#  4   Stroke            319795 non-null  object
#  5   PhysicalHealth    319795 non-null  float64
#  6   MentalHealth      319795 non-null  float64
#  7   DiffWalking       319795 non-null  object
#  8   Sex               319795 non-null  object
#  9   AgeCategory       319795 non-null  object
#  10  Race              319795 non-null  object
#  11  Diabetic          319795 non-null  object
#  12  PhysicalActivity  319795 non-null  object
#  13  GenHealth         319795 non-null  object
#  14  SleepTime         319795 non-null  float64
# ...

# %%
df.describe()
# Out:
#                  BMI  PhysicalHealth   MentalHealth      SleepTime
# count  319795.000000    319795.00000  319795.000000  319795.000000
# mean       28.325399         3.37171       3.898366       7.097075
# std         6.356100         7.95085       7.955235       1.436007
# min        12.020000         0.00000       0.000000       1.000000
# 25%        24.030000         0.00000       0.000000       6.000000
# 50%        27.340000         0.00000       0.000000       7.000000
# 75%        31.420000         2.00000       3.000000       8.000000
# max        94.850000        30.00000      30.000000      24.000000

# %% [markdown]
# ### data cleaning

# %%
df.isna().sum(axis=0)
# Out:
# HeartDisease        0
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# PhysicalHealth      0
# MentalHealth        0
# DiffWalking         0
# Sex                 0
# AgeCategory         0
# Race                0
# Diabetic            0
# PhysicalActivity    0
# GenHealth           0
# SleepTime           0
# Asthma              0
# KidneyDisease       0
# SkinCancer          0
# dtype: int64

# %%
df.nunique()
# Out:
# HeartDisease           2
# BMI                 3604
# Smoking                2
# AlcoholDrinking        2
# Stroke                 2
# PhysicalHealth        31
# MentalHealth          31
# DiffWalking            2
# Sex                    2
# AgeCategory           13
# Race                   6
# Diabetic               4
# PhysicalActivity       2
# GenHealth              5
# SleepTime             24
# Asthma                 2
# KidneyDisease          2
# SkinCancer             2
# dtype: int64

# %%
df =  df[df.columns].replace({'Yes':1, 'No':0, 'Male':1,'Female':0,'No, borderline diabetes':'0','Yes (during pregnancy)':'1' })

# %%
df.head()
# Out:
#    HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0             0  16.60        1                0       0             3.0
# 1             0  20.34        0                0       1             0.0
# 2             0  26.58        1                0       0            20.0
# 3             0  24.21        0                0       0             0.0
# 4             0  23.71        0                0       0            28.0
#
#    MentalHealth  DiffWalking  Sex  AgeCategory   Race Diabetic  \
# 0          30.0            0    0        55-59  White        1
# 1           0.0            0    0  80 or older  White        0
# 2          30.0            0    1        65-69  White        1
# 3           0.0            0    0        75-79  White        0
# 4           0.0            1    0        40-44  White        0
#
#    PhysicalActivity  GenHealth  SleepTime  Asthma  KidneyDisease  SkinCancer
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  int64
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  int64
#  3   AlcoholDrinking   319795 non-null  int64
#  4   Stroke            319795 non-null  int64
#  5   PhysicalHealth    319795 non-null  float64
#  6   MentalHealth      319795 non-null  float64
#  7   DiffWalking       319795 non-null  int64
#  8   Sex               319795 non-null  int64
#  9   AgeCategory       319795 non-null  object
#  10  Race              319795 non-null  object
#  11  Diabetic          319795 non-null  object
#  12  PhysicalActivity  319795 non-null  int64
#  13  GenHealth         319795 non-null  object
#  14  SleepTime         319795 non-null  float64
#  15  Asthma            319795 non-null  int64
# ...

# %%
df['Diabetic'] = df['Diabetic'].astype(int)

# %% [markdown]
# ### Exploratory Analysis

# %%
plt.figure(figsize=(10,6))
plt.hist(df[df["HeartDisease"]==1]['Sex'],bins=15,alpha=0.5,color='red',label='heartDisease')
plt.hist(df[df["HeartDisease"]==0]['Sex'],bins=15,alpha=0.5,color='#fccc79',label='normal')
plt.xlabel("Sex")
plt.ylabel("Frequency")

plt.title("Distribution of Cases with Yes/No heartdisease according to Sex")

plt.legend();

# %% [markdown]
# ##### that number one refers to men and 0 refers to women on the x-axis.

# %%
plt.figure(figsize=(10,6))
plt.hist(df[df["HeartDisease"]==1]["Smoking"], bins=15, alpha=0.5, color="red", label="HeartDisease")
plt.hist(df[df["HeartDisease"]==0]["Smoking"], bins=15, alpha=0.5, color="#fccc79", label="Normal")

plt.xlabel("Smoking")
plt.ylabel("Frequency")

plt.title("Distribution of Cases with Yes/No heartdisease according to being a smkoer or not.")
plt.legend();

# %% [markdown]
# #### that number one refers to smoking and 0 refers to not smoking on the x-axis.

# %%
plt.figure(figsize=(10,6))
sns.countplot( x= df['Race'], hue = 'HeartDisease', data = df, palette = 'YlOrBr')
plt.xlabel('Race')
plt.ylabel('Frequency')
plt.title("Distribution of People according to HeartDisease .")
plt.legend(['Normal','HeartDisease'])
plt.show()

# %%
plt.figure(figsize = (13,6))
sns.countplot(x = df['AgeCategory'], hue = 'HeartDisease', data = df, palette = 'YlOrBr')
fig.suptitle("Distribution of Cases with Yes/No hartdisease according to AgeCategory")
plt.xlabel('AgeCategory')
plt.legend(['Normal','HeartDisease'])
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.hist(df[df["HeartDisease"]==1]["KidneyDisease"], bins=15, alpha=0.5, color="red", label="HeartDisease")
plt.hist(df[df["HeartDisease"]==0]["KidneyDisease"], bins=15, alpha=0.5, color="#fccc79", label="Normal")

plt.xlabel("KidneyDisease")
plt.ylabel("Frequency")

plt.title("Distribution of Cases with Yes/No heartdisease according to being a KidneyDisease or not.")
plt.legend();

# %%
plt.figure(figsize=(10,6))
plt.hist(df[df["HeartDisease"]==1]["SkinCancer"], bins=15, alpha=0.5, color="red", label="HeartDisease")
plt.hist(df[df["HeartDisease"]==0]["SkinCancer"], bins=15, alpha=0.5, color="#fccc79", label="Normal")

plt.xlabel("SkinCancer")
plt.ylabel("Frequency")

plt.title("Distribution of Cases with Yes/No heartdisease according to being a SkinCancer or not.")
plt.legend();

# %%
plt.figure(figsize=(10,6))
plt.hist(df[df["HeartDisease"]==1]["Stroke"], bins=15, alpha=0.5, color="red", label="HeartDisease")
plt.hist(df[df["HeartDisease"]==0]["Stroke"], bins=15, alpha=0.5, color="#fccc79", label="Normal")

plt.xlabel("Stroke")
plt.ylabel("Frequency")

plt.title("Distribution of Cases with Yes/No heartdisease according to being a Stroke or not.")
plt.legend();

# %%
plt.figure(figsize=(10,6))
plt.hist(df[df["HeartDisease"]==1]["Diabetic"], bins=15, alpha=0.5, color="red", label="HeartDisease")
plt.hist(df[df["HeartDisease"]==0]["Diabetic"], bins=15, alpha=0.5, color="#fccc79", label="Normal")

plt.xlabel("Diabetic")
plt.ylabel("Frequency")

plt.title("Distribution of Cases with Yes/No heartdisease according to being a Diabetic or not.")
plt.legend();

# %%
df_1=df

# %%
df_1=df_1.drop("AgeCategory",axis=1)
df_1=df_1.drop("Race",axis=1)
df_1=df_1.drop("GenHealth",axis=1)

# %%
df_1.head()
# Out:
#    HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0             0  16.60        1                0       0             3.0
# 1             0  20.34        0                0       1             0.0
# 2             0  26.58        1                0       0            20.0
# 3             0  24.21        0                0       0             0.0
# 4             0  23.71        0                0       0            28.0
#
#    MentalHealth  DiffWalking  Sex  Diabetic  PhysicalActivity  SleepTime  \
# 0          30.0            0    0         1                 1        5.0
# 1           0.0            0    0         0                 1        7.0
# 2          30.0            0    1         1                 1        8.0
# 3           0.0            0    0         0                 0        6.0
# 4           0.0            1    0         0                 1        8.0
#
#    Asthma  KidneyDisease  SkinCancer
# 0       1              0           1
# ...

# %%
correlation = df_1.corr().round(2)
plt.figure(figsize = (10,6))
sns.heatmap(correlation, annot = True, cmap = 'YlOrBr');

# %%
df.head()
# Out:
#    HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0             0  16.60        1                0       0             3.0
# 1             0  20.34        0                0       1             0.0
# 2             0  26.58        1                0       0            20.0
# 3             0  24.21        0                0       0             0.0
# 4             0  23.71        0                0       0            28.0
#
#    MentalHealth  DiffWalking  Sex  AgeCategory   Race  Diabetic  \
# 0          30.0            0    0        55-59  White         1
# 1           0.0            0    0  80 or older  White         0
# 2          30.0            0    1        65-69  White         1
# 3           0.0            0    0        75-79  White         0
# 4           0.0            1    0        40-44  White         0
#
#    PhysicalActivity  GenHealth  SleepTime  Asthma  KidneyDisease  SkinCancer
# ...

# %%
sns.set_style('whitegrid')
sns.set_palette('YlOrBr')
plt.figure(figsize = (13,6))
plt.title('Distribution of correlation of features')
abs(correlation['HeartDisease']).sort_values()[:-1].plot.barh()
plt.show()

# %% [markdown]
# ###### highest corr

# %%
highest_corr_feature = abs(correlation['HeartDisease']).sort_values()[:-1].index[-1]
highest_corr_value = abs(correlation['HeartDisease']).sort_values()[:-1][-1]

print(f"The feature with the highest absolute correlation is {highest_corr_feature} with a correlation value of {highest_corr_value:.2f}")
# Out:
# The feature with the highest absolute correlation is DiffWalking with a correlation value of 0.20

# %%
plt.figure(figsize=(10,6))
sns.kdeplot(df[df["HeartDisease"]==1]["BMI"], alpha=0.5,shade = True, color="red", label="HeartDisease" )
sns.kdeplot(df[df["HeartDisease"]==0]["BMI"], alpha=0.5,shade = True, color="#fccc79", label="Normal" )
plt.title('Distribution of Body Mass Index', fontsize = 18)
plt.xlabel("BodyMass")
plt.ylabel("Frequency")
plt.legend()
plt.show();
# Out:
# C:\Users\Softlaptop\AppData\Local\Temp\ipykernel_9048\3152038284.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[df["HeartDisease"]==1]["BMI"], alpha=0.5,shade = True, color="red", label="HeartDisease" )
# C:\Users\Softlaptop\AppData\Local\Temp\ipykernel_9048\3152038284.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[df["HeartDisease"]==0]["BMI"], alpha=0.5,shade = True, color="#fccc79", label="Normal" )

# %%
plt.figure(figsize=(10,6))
sns.kdeplot(df[df["HeartDisease"]==1]["DiffWalking"], alpha=0.5,shade = True, color="red", label="HeartDisease" )
sns.kdeplot(df[df["HeartDisease"]==0]["DiffWalking"], alpha=0.5,shade = True, color="#fccc79", label="Normal" )
plt.title('Distribution of DiffWalking', fontsize = 18)
plt.xlabel("DiffWalking")
plt.ylabel("Frequency")
plt.legend()
plt.show();
# Out:
# C:\Users\Softlaptop\AppData\Local\Temp\ipykernel_9048\599919758.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[df["HeartDisease"]==1]["DiffWalking"], alpha=0.5,shade = True, color="red", label="HeartDisease" )
# C:\Users\Softlaptop\AppData\Local\Temp\ipykernel_9048\599919758.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[df["HeartDisease"]==0]["DiffWalking"], alpha=0.5,shade = True, color="#fccc79", label="Normal" )

# %%
plt.figure(figsize=(10,6))
sns.kdeplot(df[df["HeartDisease"]==1]["MentalHealth"], alpha=0.5,shade = True, color="red", label="HeartDisease" )
sns.kdeplot(df[df["HeartDisease"]==0]["MentalHealth"], alpha=0.5,shade = True, color="#fccc79", label="Normal" )
plt.title('Distribution of MentalHealth', fontsize = 18)
plt.xlabel("MentalHealth")
plt.ylabel("Frequency")
plt.legend()
plt.show();
# Out:
# C:\Users\Softlaptop\AppData\Local\Temp\ipykernel_9048\2709473031.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[df["HeartDisease"]==1]["MentalHealth"], alpha=0.5,shade = True, color="red", label="HeartDisease" )
# C:\Users\Softlaptop\AppData\Local\Temp\ipykernel_9048\2709473031.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[df["HeartDisease"]==0]["MentalHealth"], alpha=0.5,shade = True, color="#fccc79", label="Normal" )

# %%
plt.figure(figsize=(10,6))
sns.kdeplot(df[df["HeartDisease"]==1]["PhysicalHealth"], alpha=0.5,shade = True, color="red", label="HeartDisease" )
sns.kdeplot(df[df["HeartDisease"]==0]["PhysicalHealth"], alpha=0.5,shade = True, color="#fccc79", label="Normal" )
plt.title('Distribution of PhysicalHealth', fontsize = 18)
plt.xlabel("PhysicalHealth")
plt.ylabel("Frequency")
plt.legend()
plt.show();
# Out:
# C:\Users\Softlaptop\AppData\Local\Temp\ipykernel_9048\1861413526.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[df["HeartDisease"]==1]["PhysicalHealth"], alpha=0.5,shade = True, color="red", label="HeartDisease" )
# C:\Users\Softlaptop\AppData\Local\Temp\ipykernel_9048\1861413526.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[df["HeartDisease"]==0]["PhysicalHealth"], alpha=0.5,shade = True, color="#fccc79", label="Normal" )

# %% [markdown]
# #### Data Preprocessing

# %%
age=pd.get_dummies(df['AgeCategory'],drop_first=True)
race=pd.get_dummies(df['Race'],drop_first=True)
gen_health=pd.get_dummies(df['GenHealth'],drop_first=True)

# %%
df=pd.concat([df,age,race,gen_health],axis=1)

# %%
df.drop(['AgeCategory','Race', 'GenHealth'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0             0  16.60        1                0       0             3.0
# 1             0  20.34        0                0       1             0.0
# 2             0  26.58        1                0       0            20.0
# 3             0  24.21        0                0       0             0.0
# 4             0  23.71        0                0       0            28.0
#
#    MentalHealth  DiffWalking  Sex  Diabetic  ...  80 or older  Asian  Black  \
# 0          30.0            0    0         1  ...        False  False  False
# 1           0.0            0    0         0  ...         True  False  False
# 2          30.0            0    1         1  ...        False  False  False
# 3           0.0            0    0         0  ...        False  False  False
# 4           0.0            1    0         0  ...        False  False  False
#
#    Hispanic  Other  White   Fair   Good   Poor  Very good
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 36 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  int64
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  int64
#  3   AlcoholDrinking   319795 non-null  int64
#  4   Stroke            319795 non-null  int64
#  5   PhysicalHealth    319795 non-null  float64
#  6   MentalHealth      319795 non-null  float64
#  7   DiffWalking       319795 non-null  int64
#  8   Sex               319795 non-null  int64
#  9   Diabetic          319795 non-null  int32
#  10  PhysicalActivity  319795 non-null  int64
#  11  SleepTime         319795 non-null  float64
#  12  Asthma            319795 non-null  int64
#  13  KidneyDisease     319795 non-null  int64
#  14  SkinCancer        319795 non-null  int64
#  15  25-29             319795 non-null  bool
# ...

# %% [markdown]
# #### Split Dataset for Training and Testing

# %%
#Select Features
features = df.drop(columns =['HeartDisease'], axis = 1)

#Select Target 
target = df['HeartDisease']

# Set Training and Testing Data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features, target, shuffle = True, test_size = .2, random_state = 44)


print('Shape of training feature:', X_train.shape)
print('Shape of testing feature:', X_test.shape)
print('Shape of training label:', y_train.shape)
print('Shape of training label:', y_test.shape)
# Out:
# Shape of training feature: (255836, 35)
# Shape of testing feature: (63959, 35)
# Shape of training label: (255836,)
# Shape of training label: (63959,)

# %% [markdown]
#  #### standardization

# %%
from sklearn.preprocessing import StandardScaler 

scaler = StandardScaler()

# Scale trainint data
X_train = scaler.fit_transform(X_train)

# Scale test data
X_test = scaler.fit_transform(X_test)

# %% [markdown]
# #### Modling

# %%
 def evaluate_model(model, x_test, y_test):
    from sklearn import metrics

    # Predict Test Data 
    y_pred = model.predict(x_test)

    # Calculate accuracy, precision, recall, f1-score, and kappa score
    acc = metrics.accuracy_score(y_test, y_pred)
    prec = metrics.precision_score(y_test, y_pred)
    rec = metrics.recall_score(y_test, y_pred)
    f1 = metrics.f1_score(y_test, y_pred)
    kappa = metrics.cohen_kappa_score(y_test, y_pred)

    # Calculate area under curve (AUC)
    y_pred_proba = model.predict_proba(x_test)[::,1]
    fpr, tpr, _ = metrics.roc_curve(y_test, y_pred_proba)
    auc = metrics.roc_auc_score(y_test, y_pred_proba)

    # Display confussion matrix
    cm = metrics.confusion_matrix(y_test, y_pred)

    return {'acc': acc, 'prec': prec, 'rec': rec, 'f1': f1, 'kappa': kappa, 
            'fpr': fpr, 'tpr': tpr, 'auc': auc, 'cm': cm}

# %%
from sklearn.neighbors import KNeighborsClassifier

# Building a model using KNeighborsClassifier 
knn = KNeighborsClassifier(n_neighbors = 5)

knn.fit(X_train, y_train)


# Evaluate Model
knn_eval = evaluate_model(knn, X_test, y_test)

# Print result
print('Accuracy:', knn_eval['acc'])
print('Precision:', knn_eval['prec'])
print('Recall:', knn_eval['rec'])
print('F1 Score:', knn_eval['f1'])
print('Cohens Kappa Score:', knn_eval['kappa'])
print('Area Under Curve:', knn_eval['auc'])
print('Confusion Matrix:\n', knn_eval['cm'])
# Out:
# Accuracy: 0.9050172766928813
# Precision: 0.35310602522185897
# Recall: 0.13881748071979436
# F1 Score: 0.199288256227758
# Cohens Kappa Score: 0.15886627488711613
# Area Under Curve: 0.7178308364405828
# Confusion Matrix:
#  [[57128  1385]
#  [ 4690   756]]

# %%
from sklearn import tree
# Building Decision Tree model 
clf = tree.DecisionTreeClassifier(random_state=0)
clf.fit(X_train, y_train)

# Evaluate Model
clf_eval = evaluate_model(clf, X_test, y_test)

# Print result
print('Accuracy:', clf_eval['acc'])
print('Precision:', clf_eval['prec'])
print('Recall:', clf_eval['rec'])
print('F1 Score:', clf_eval['f1'])
print('Cohens Kappa Score:', clf_eval['kappa'])
print('Area Under Curve:', clf_eval['auc'])
print('Confusion Matrix:\n', clf_eval['cm'])# Evaluate Model
# Out:
# Accuracy: 0.8644913147485108
# Precision: 0.2304602510460251
# Recall: 0.2528461255967683
# F1 Score: 0.24113475177304963
# Cohens Kappa Score: 0.16691320580584346
# Area Under Curve: 0.5881062922390214
# Confusion Matrix:
#  [[53915  4598]
#  [ 4069  1377]]

# %%
# Intitialize figure with two plots
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('Model Comparison', fontsize=16, fontweight='bold')
fig.set_figheight(7)
fig.set_figwidth(14)
fig.set_facecolor('white')

# First plot
## set bar size
barWidth = 0.2
clf_score = [clf_eval['acc'], clf_eval['prec'], clf_eval['rec'], clf_eval['f1'], clf_eval['kappa']]
knn_score = [knn_eval['acc'], knn_eval['prec'], knn_eval['rec'], knn_eval['f1'], knn_eval['kappa']]


## Set position of bar on X axis
r1 = np.arange(len(clf_score))
r2 = [x + barWidth for x in r1]

## Make the plot
ax1.bar(r1, clf_score, width=barWidth, edgecolor='white', label='Decision Tree')
ax1.bar(r2, knn_score, width=barWidth, edgecolor='white', label='K-Nearest Neighbors')

## Configure x and y axis
ax1.set_xlabel('Metrics', fontweight='bold')
labels = ['Accuracy', 'Precision', 'Recall', 'F1', 'Kappa']
ax1.set_xticks([r + (barWidth * 1.5) for r in range(len(clf_score))], )
ax1.set_xticklabels(labels)
ax1.set_ylabel('Score', fontweight='bold')
ax1.set_ylim(0, 1)

## Create legend & title
ax1.set_title('Evaluation Metrics', fontsize=14, fontweight='bold')
ax1.legend()

# Second plot
## Comparing ROC Curve
ax2.plot(clf_eval['fpr'], clf_eval['tpr'], label='Decision Tree, auc = {:0.5f}'.format(clf_eval['auc']))
ax2.plot(knn_eval['fpr'], knn_eval['tpr'], label='K-Nearest Nieghbor, auc = {:0.5f}'.format(knn_eval['auc']))

## Configure x and y axis
ax2.set_xlabel('False Positive Rate', fontweight='bold')
ax2.set_ylabel('True Positive Rate', fontweight='bold')

## Create legend & title
ax2.set_title('ROC Curve', fontsize=14, fontweight='bold')
ax2.legend(loc=4)

plt.show()
